# %%
from mySqlCrudUtils import mySqlCrudUtils

# %%
oss_active_alarm_africa = mySqlCrudUtils(host = '10.129.4.24', user = 'root', password = 'DBServer@424', database = 'oss_active_alarm_africa')

# %%
oss_active_alarm_africa.read(tableName = 'bcf_alarm', fetchone = True)
# Out:
# {'CIRCLE': '399866',
#  'BSC': 'NBSC10',
#  'BCFID': '1330',
#  'SITE': 'AMBALAKIDA',
#  'ALARM_TIME': '2024-11-05 16:13:05',
#  'ALARM_DIFF': '6 Days 13 Hrs 33 Min ',
#  'ALARM_NO': '7729',
#  'CONSEC': '109673688',
#  'STATE_IN_MODE': 'U',
#  'SEV': '***',
#  'DESC': 'RADIO NETWORK RECOVERY FAILED',
#  'SUPPLY_INFO': '65535d FFFF FFFF 01 11356d',
#  'CIR': 'MADAGASCAR'}
